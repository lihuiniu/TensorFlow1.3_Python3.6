# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
#python2
#import urllib

#python 3 need to import urllib.request 
import urllib.request

import tensorflow as tf
import numpy as np

IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL="http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL="http://download.tensorflow.org/data/iris_test.csv"

if not os.path.exists(IRIS_TRAINING):
    #python2
    #raw = urllib.urlopen(IRIS_TRAINING_URL).read()
    raw = urllib.request.urlopen(IRIS_TRAINING_URL).read().decode() #python3
    
    with open(IRIS_TRAINING, 'w') as f:
        f.write(raw)
if not os.path.exists(IRIS_TEST):
    #python2
    #raw = urllib.urlopen(IRIS_TEST_URL).read()
    raw = urllib.request.urlopen(IRIS_TEST_URL).read().decode() #python3
    with open(IRIS_TEST, 'w') as f:
        f.write(raw)

#Load datasets.
training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TRAINING,
    target_dtype=np.int,
    features_dtype=np.float32)
test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
    filename=IRIS_TEST,
    target_dtype=np.int,
    features_dtype=np.float32)

#Construct a DNN Classfier

#Specify that all features have real-value data
#4 features: sepal width, sepal height, petal width, petal height.
feature_columns = [tf.feature_column.numeric_column("x", shape=[4])]

#Build 3 hidden layer DNN with 10, 20, 10 units respectively.
classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns,
                                       hidden_units=[10, 20, 10],
                                       n_classes = 3,
                                       model_dir="/tmp/iris_model")

#Define the training inputs
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": np.array(training_set.data)},
    y=np.array(training_set.target),
    num_epochs=None,
    shuffle=True)

#Train model.
classifier.train(input_fn=train_input_fn, steps=2000)

#Define the test inputs
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": np.array(test_set.data)},
    y=np.array(test_set.target),
    num_epochs=1,
    shuffle=False)

#Evaluate accuracy.
accuracy_score = classifier.evaluate(input_fn=test_input_fn)["accuracy"]

print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

#Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5],
    [5.8, 3.1, 5.0, 1.7]],
    dtype=np.float32)
predict_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": new_samples},
    num_epochs=1,
    shuffle=False)
predictions = list(classifier.predict(input_fn=predict_input_fn))
predicted_classes = [p["classes"] for p in predictions]

print("New Samples, Class Predictions: {}\n".format(predicted_classes))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/iris_model', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-6000
# INFO:tensorflow:Saving checkpoints for 6001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 2.93485, step = 6001
# INFO:tensorflow:global_step/sec: 500.704
# INFO:tensorflow:loss = 4.77626, step = 6101 (0.201 sec)
# INFO:tensorflow:global_step/sec: 585.515
# INFO:tensorflow:loss = 5.73114, step = 6201 (0.171 sec)
# INFO:tensorflow:global_step/sec: 640.476
# INFO:tensorflow:loss = 4.79008, step = 6301 (0.156 sec)
# INFO:tensorflow:global_step/sec: 629.449
# INFO:tensorflow:loss = 4.62166, step = 6401 (0.159 sec)
# INFO:tensorflow:global_step/sec: 639.41
# INFO:tensorflow:loss = 6.01041, step = 6501 (0.156 sec)
# INFO:tensorflow:global_step/sec: 646.234
# INFO:tensorflow:loss = 4.15879, step = 6601 (0.154 sec)
# INFO:tensorflow:global_step/sec: 653.184
# INFO:tensorflow:loss = 6.12755, step = 6701 (0.153 sec)
# INFO:tensorflow:global_step/sec: 661.04
# INFO:tensorflow:loss = 9.19392, step = 6801 (0.152 sec)
# INFO:tensorflow:global_step/sec: 687.739
# INFO:tensorflow:loss = 1.69965, step = 6901 (0.145 sec)
# INFO:tensorflow:global_step/sec: 683.888
# INFO:tensorflow:loss = 2.65262, step = 7001 (0.146 sec)
# INFO:tensorflow:global_step/sec: 736.457
# INFO:tensorflow:loss = 1.5125, step = 7101 (0.136 sec)
# INFO:tensorflow:global_step/sec: 645.595
# INFO:tensorflow:loss = 6.9233, step = 7201 (0.154 sec)
# INFO:tensorflow:global_step/sec: 560.761
# INFO:tensorflow:loss = 3.43346, step = 7301 (0.179 sec)
# INFO:tensorflow:global_step/sec: 588.122
# INFO:tensorflow:loss = 6.30286, step = 7401 (0.170 sec)
# INFO:tensorflow:global_step/sec: 596.805
# INFO:tensorflow:loss = 0.820558, step = 7501 (0.167 sec)
# INFO:tensorflow:global_step/sec: 605.084
# INFO:tensorflow:loss = 2.78803, step = 7601 (0.166 sec)
# INFO:tensorflow:global_step/sec: 595.6
# INFO:tensorflow:loss = 6.10984, step = 7701 (0.168 sec)
# INFO:tensorflow:global_step/sec: 580.172
# INFO:tensorflow:loss = 6.1999, step = 7801 (0.172 sec)
# INFO:tensorflow:global_step/sec: 618.288
# INFO:tensorflow:loss = 3.34783, step = 7901 (0.161 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.96789.
# INFO:tensorflow:Starting evaluation at 2017-10-08-07:23:20
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-8000
# INFO:tensorflow:Finished evaluation at 2017-10-08-07:23:20
# INFO:tensorflow:Saving dict for global step 8000: accuracy = 0.966667, average_loss = 0.0941399, global_step = 8000, loss = 2.8242
#
# Test Accuracy: 0.966667
#
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-8000
# New Samples, Class Predictions: [array([b'1'], dtype=object), array([b'2'], dtype=object)]

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import urllib.request

import numpy as np
import tensorflow as tf

# Data sets
IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

#g = urllib.request.urlopen('http://media-mcw.cursecdn.com/3/3f/Beta.png')
#with open('test.png', 'b+w') as f:
#    f.write(g.read())
def main():
  # If the training and test sets aren't stored locally, download them.
  if not os.path.exists(IRIS_TRAINING):
    raw = urllib.request.urlopen(IRIS_TRAINING_URL).read()
    with open(IRIS_TRAINING, "wb") as f:
      f.write(raw)
    
  if not os.path.exists(IRIS_TEST):
    raw = urllib.request.urlopen(IRIS_TEST_URL).read()
    with open(IRIS_TEST, "wb") as f:
      f.write(raw)
    
  # Load datasets.
  training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
      filename=IRIS_TRAINING,
      target_dtype=np.int,
      features_dtype=np.float32)
  test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
      filename=IRIS_TEST,
      target_dtype=np.int,
      features_dtype=np.float32)

  # Specify that all features have real-value data
  feature_columns = [tf.feature_column.numeric_column("x", shape=[4])]

  # Build 3 layer DNN with 10, 20, 10 units respectively.
  classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns,
                                          hidden_units=[10, 20, 10],
                                          n_classes=3,
                                          model_dir="/tmp/iris_model")
  # Define the training inputs
  train_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": np.array(training_set.data)},
      y=np.array(training_set.target),
      num_epochs=None,
      shuffle=True)

  # Train model.
  classifier.train(input_fn=train_input_fn, steps=2000)

  # Define the test inputs
  test_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": np.array(test_set.data)},
      y=np.array(test_set.target),
      num_epochs=1,
      shuffle=False)

  # Evaluate accuracy.
  accuracy_score = classifier.evaluate(input_fn=test_input_fn)["accuracy"]

  print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

  # Classify two new flower samples.
  new_samples = np.array(
      [[6.4, 3.2, 4.5, 1.5],
       [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)
  predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": new_samples},
      num_epochs=1,
      shuffle=False)

  predictions = list(classifier.predict(input_fn=predict_input_fn))
  predicted_classes = [p["classes"] for p in predictions]

  print(
      "New Samples, Class Predictions:    {}\n"
      .format(predicted_classes))

if __name__ == "__main__":
    main()
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/iris_model', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-2000
# INFO:tensorflow:Saving checkpoints for 2001 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:loss = 6.33134, step = 2001
# INFO:tensorflow:global_step/sec: 546.271
# INFO:tensorflow:loss = 3.69799, step = 2101 (0.185 sec)
# INFO:tensorflow:global_step/sec: 641.429
# INFO:tensorflow:loss = 3.08897, step = 2201 (0.156 sec)
# INFO:tensorflow:global_step/sec: 672.223
# INFO:tensorflow:loss = 11.667, step = 2301 (0.149 sec)
# INFO:tensorflow:global_step/sec: 648.593
# INFO:tensorflow:loss = 7.18146, step = 2401 (0.154 sec)
# INFO:tensorflow:global_step/sec: 636.894
# INFO:tensorflow:loss = 2.75844, step = 2501 (0.157 sec)
# INFO:tensorflow:global_step/sec: 680.726
# INFO:tensorflow:loss = 8.66945, step = 2601 (0.147 sec)
# INFO:tensorflow:global_step/sec: 681.133
# INFO:tensorflow:loss = 4.84395, step = 2701 (0.147 sec)
# INFO:tensorflow:global_step/sec: 666.903
# INFO:tensorflow:loss = 2.23132, step = 2801 (0.151 sec)
# INFO:tensorflow:global_step/sec: 642.835
# INFO:tensorflow:loss = 5.21542, step = 2901 (0.154 sec)
# INFO:tensorflow:global_step/sec: 663.681
# INFO:tensorflow:loss = 3.60364, step = 3001 (0.152 sec)
# INFO:tensorflow:global_step/sec: 621.939
# INFO:tensorflow:loss = 5.55902, step = 3101 (0.160 sec)
# INFO:tensorflow:global_step/sec: 642.25
# INFO:tensorflow:loss = 10.2611, step = 3201 (0.156 sec)
# INFO:tensorflow:global_step/sec: 622.982
# INFO:tensorflow:loss = 7.29521, step = 3301 (0.160 sec)
# INFO:tensorflow:global_step/sec: 730.07
# INFO:tensorflow:loss = 3.35041, step = 3401 (0.137 sec)
# INFO:tensorflow:global_step/sec: 673.175
# INFO:tensorflow:loss = 2.39519, step = 3501 (0.149 sec)
# INFO:tensorflow:global_step/sec: 612.377
# INFO:tensorflow:loss = 5.25395, step = 3601 (0.165 sec)
# INFO:tensorflow:global_step/sec: 579.602
# INFO:tensorflow:loss = 3.1929, step = 3701 (0.170 sec)
# INFO:tensorflow:global_step/sec: 594.128
# INFO:tensorflow:loss = 3.47623, step = 3801 (0.168 sec)
# INFO:tensorflow:global_step/sec: 626.096
# INFO:tensorflow:loss = 6.33525, step = 3901 (0.160 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into /tmp/iris_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.06458.
# INFO:tensorflow:Starting evaluation at 2017-10-08-07:16:45
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-4000
# INFO:tensorflow:Finished evaluation at 2017-10-08-07:16:45
# INFO:tensorflow:Saving dict for global step 4000: accuracy = 0.966667, average_loss = 0.0555975, global_step = 4000, loss = 1.66793
#
# Test Accuracy: 0.966667
#
# INFO:tensorflow:Restoring parameters from /tmp/iris_model/model.ckpt-4000
# New Samples, Class Predictions:    [array([b'1'], dtype=object), array([b'2'], dtype=object)]
